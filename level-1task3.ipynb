# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(r"P:\videos\Dataset.csv")
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
price_ranges = df["Price range"].value_counts()
#Plotting Bar Graph for the Number of restaurants and Price Range
plt.bar(price_ranges.index, price_ranges.values)
plt.title("Distribution of Price Ranges")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.show()

# %%
#Plotting Histogram for the Number of restaurants and Price Range
plt.hist(price_ranges)
plt.title("Distribution of Price Ranges")
plt.xlabel("Price Range")
plt.ylabel("Number of Restaurants")
plt.show()

# %%
#Calculating the percentage of restaurants in each price range category
percentages = price_ranges / len(df) * 100
for price_range, percentage in percentages.items():
    print(f"{price_range}: {percentage}%")
# Out:
# 1: 46.52915925034028%
# 2: 32.59344571249084%
# 3: 14.741911841691968%
# 4: 6.135483195476914%
